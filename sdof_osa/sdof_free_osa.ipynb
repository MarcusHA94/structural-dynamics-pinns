# %% [markdown]
# # Linear SDOF PINN - n-step ahead prediction
#
# ## Problem overview
#
# The example problem we solve here is the SDOF cubic oscillator:
# $$
# m \ddot{x} + c\dot{x} + kx = 0~, \qquad \ddot{x} + \tilde{c}\dot{x} + \tilde{k}x = 0~, \qquad \tilde{\bullet}=\frac{\bullet}{m}
# $$
# with the initial conditions
# $$
# x(0) = x_0~~,~~\dot{x}(0) = \dot{x}_0
# $$
#
# The aim is to predict the output at one-step ahead, using the previous displacement and velocity;
# $$
# x_{n+1} = f(x_{n},\dot{x}_{n})
# $$
#
# For notation with the neural networks, we will denote,
# $$
# y = x_{n+1}, \qquad \mathbf{x} = \{ x_{n},\dot{x}_{n} \}
# $$

# %%
from osa_pinn import bbnn, osa_pinn_sdof, normalise, ParamClipper
from sdof_oscillators import sdof_solution, add_noise, generate_excitation

import numpy as np
import torch
import torch.nn as nn

from scipy.stats import qmc

from tqdm import tqdm
from tqdm.auto import tqdm as tqdma

import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
nt = 256
time = np.linspace(0,60,nt)

F0 = 1.0  # N

excitation = {
    "type" : "sinusoid",
    "F0" : F0,
    "w" : 1.6  # rad/s
}

F = generate_excitation(time, **excitation)
excitation["F"] = F.reshape(-1)
### Generate training/ground truth data
m = 10.0
c = 0.75
k = 15.0
excitation["F_tild"] = excitation["F"]/m

wn = np.sqrt(k/m)
zeta = c/(2*m*wn)
wd = wn*np.sqrt(1-zeta**2)

k_tild = k/m
c_tild = c/m

config = {
    "time_" : time,
    "nonlinearity" : "linear",
    "m_norm" : True,
    "params" : {
        "m" : m,
        "k" : k,
        "c" : c,
        "k_tild" : k_tild,
        "c_tild" : c_tild
    },
    "init_conds" : {
        "x0" : 0.01,
        "v0" : 0.05
    },
    "forcing" : None
}

xx, vv = sdof_solution(time, **config)
time = torch.tensor(time).view(-1,1).to(torch.float32)

# slice out a number of points
# sampler = qmc.Sobol(d=1)
# sub_ind = np.sort(sampler.integers(l_bounds=nt, n=int(nt/8)), axis=0)
sub_ind = np.arange(0, int(nt/1), 2)

t_data = time[sub_ind]
x_data = xx[sub_ind]
v_data = vv[sub_ind]

T = t_data[1].item()-t_data[0].item()

fig, axs = plt.subplots(2,1,figsize=(12,8))

axs[0].plot(time, xx, color="tab:blue", label="Displacement")
axs[0].scatter(t_data, x_data, color="tab:orange", label="Training data")
axs[0].legend()

axs[1].plot(time, vv, color="tab:red", label="Velocity")
axs[1].scatter(t_data, v_data, color="tab:orange", label="Training data")
axs[1].legend()

# %% [markdown]
# Normalise and create some plotting functions

# %%
t_hat, alpha_t = normalise(time, "range")
x_hat_gt, alpha_x = normalise(xx, "range")
v_hat_gt, alpha_v = normalise(vv, "range")

t_data = t_hat[sub_ind]
x_data = x_hat_gt[sub_ind]
v_data = v_hat_gt[sub_ind]

T_hat = t_data[1].item()-t_data[0].item()

fig, axs = plt.subplots(2,1,figsize=(12,8))

axs[0].plot(t_hat, x_hat_gt, color="tab:blue", label="Displacement")
axs[0].scatter(t_data, x_data, color="tab:orange", label="Training data")
axs[0].legend()

axs[1].plot(t_hat, v_hat_gt, color="tab:red", label="Velocity")
axs[1].scatter(t_data, v_data, color="tab:orange", label="Training data")
axs[1].legend()

# %%
def plot_joint_loss_hist(ax,loss_hist):
    n_epoch = len(loss_hist)
    labels = ["L_obs", "L_ic", "L_ode", "L"]
    colors = ["tab:blue", "tab:red", "tab:green", "black"]
    # labels = ["L_obs", "L_ic", "L_ode", "L_ed_b", "L_ed_p", "L"]
    # colors = ["tab:blue", "tab:red", "tab:green", "tab:orange", "tab:purple", "black"]
    ax.cla()
    for i in range(len(labels)):
        ax.plot(np.arange(1,n_epoch+1),loss_hist[:,i],color=colors[i],label=labels[i])
    ax.set_yscale('log')
    ax.legend()

def plot_result(ax, ground_truth, data, prediction, alphas, var_pred=None):
    ax.cla()
    ax.plot(ground_truth["t_hat"]*alphas["t"], ground_truth["x_hat"]*alphas["x"], color="grey", linewidth=1, alpha=0.8, label="Exact solution")
    ax.plot(prediction["t_hat"]*alphas["t"], prediction["x_hat"]*alphas["x"], color="tab:blue", linewidth=1, alpha=0.8, label="Neural network prediction")
    ax.scatter(data["t_hat"]*alphas["t"], data["x_hat"]*alphas["x"], s=60, color="tab:orange", alpha=0.4, label='Training data')
    if var_pred is not None:
        ax.plot(var_pred["t_hat"]*alphas["t"], var_pred["x_hat"]*alphas["x"], color="tab:cyan", alpha=0.4, label='Variable coll prediction')
    l = ax.legend(frameon=False, fontsize="large")
    xL = torch.amax(ground_truth["t_hat"])*alphas["t"]
    yL = torch.amax(torch.abs(ground_truth["x_hat"]))*alphas["x"]
    ax.set_xlim(-0.05*xL, 1.05*xL)
    ax.set_ylim(-1.1*yL, 1.1*yL)

ground_truth = {
    "t_hat" : t_hat,
    "x_hat" : x_hat_gt,
    "v_hat" : v_hat_gt,
    "F_hat" : None
}

data = {
    "t_hat" : t_data,
    "x_hat" : x_data,
    "v_hat" : v_data,
    "F_hat" : None,
    "sub_ind" : sub_ind
}

# %% [markdown]
# ## PINN
#
# $$
# \mathcal{L}(x_0,v_0,t;\mathbf{\theta}) := \mathcal{L}_{obs} + \mathcal{L}_{ic} + \Lambda\mathcal{L}_{ode}
# $$
#
# $$
# \mathcal{L}_{obs} = \langle \hat{x}^* - \mathcal{N}_{\hat{x}} \rangle _{\Omega\in\{t=T\}}, \qquad
# \mathcal{L}_{ic} = \langle \alpha_{v}\hat{v}_0 - \frac{\alpha_x}{\alpha_t}\partial_{\hat{t}}\mathcal{N}_{\hat{x}} \rangle _{\Omega\in\{t=0\}}
# $$
# $$
# \mathcal{L}_{ode} = \langle \hat{m} \partial^2_{\hat{t}}\mathcal{N}_{\hat{x}} + \hat{c} \partial_{\hat{t}}\mathcal{N}_{\hat{x}} + \hat{k}\mathcal{N}_{\hat{x}} - \eta \hat{F}\rangle _{\Omega_d}
# $$
# where,
# $$ \mathcal{N}_{\bullet} = \mathcal{N}_{\bullet}(\mathbf{x};\mathbf{\theta}), \qquad
# \partial_{*}\bullet = \frac{\partial\bullet}{\partial *}, \qquad
# \partial^2_{*}\bullet = \frac{\partial^2\bullet}{\partial *^2}, \qquad
# \langle\bullet\rangle _{\Omega_{\kappa}} = \frac{1}{N_{\kappa}}\sum_{x\in\Omega_{\kappa}}\left|\left|\bullet\right|\right|^2 $$
#
# ODE loss function comes from including the normalisation of the parameters, then choosing the suitable range to aid optimisation.
#
# $$
# \frac{1}{\alpha_t^2} \partial^2_{\hat{t}}\hat{x} +
# \tilde{c}\frac{1}{\alpha_t}\partial_{\hat{t}}\hat{x} +
# \tilde{k} \hat{x} -
# \frac{\alpha_F}{\alpha_x} \hat{F} = 0
# \quad \rightarrow \quad
# \hat{m} \partial^2_{\hat{t}}\hat{x} +
# \hat{c} \partial_{\hat{t}}\hat{x} +
# \hat{k}\hat{x} - \eta\hat{F} = 0
# $$
# To scale loss function in a physically meaningful way, multiply the loss function by any of the following:
# $$
# \Lambda = 1, \alpha_t, \alpha_t^2, \alpha_x^, \alpha_F^{-1}
# $$

# %%
alpha_c = c_tild*10
alpha_k = k_tild*10
alphas = {
    "c" : alpha_c,
    "k" : alpha_k,
    "t" : alpha_t,
    "x" : alpha_x,
    "v" : alpha_v,
    "F" : 1.0
}

nct = 4  # number of collocation points in time window

torch.manual_seed(123)

osa_config = {
    "n_input" : 3,
    "n_output" : 1,
    "n_hidden" : 8,
    "n_layers" : 2,
    "T" : T,
    "T_hat" : T_hat,
    "nct" : nct,
    "nonlinearity" : "linear",
    # "phys_params" : {
    #     "par_type" : "variable",
    #     "k": 1.0,
    #     "c" : 1.0,
    #     "ed_nct" : 1024
    # },
    "phys_params" : {
        "par_type" : "constant",
        "k": k_tild,
        "c" : c_tild
    },
    "alphas" : alphas,
    "ode_norm_Lambda" : alpha_x.item(),
    "forcing" : config["forcing"]
}

# configure PINN
osa_model = osa_pinn_sdof(osa_config)
t_pred = osa_model.set_colls_and_obs(t_data, x_data, v_data)

# configure optimiser
learning_rate = 2e-4
betas = (0.9,0.999)
optimizer = torch.optim.Adam(osa_model.parameters(), lr=learning_rate, betas=betas)

clipper = ParamClipper()

# learning_rate = 5e-3
# max_iter = 50
# optimizer = torch.optim.LBFGS(osa_model.parameters(), lr=learning_rate, max_iter=max_iter)

fig, axs = plt.subplots(1,2,figsize=(18,6),facecolor='w')
print_step = 200
loss_hist=[]
lambds = {
    'obs' : 1000.0,
    'ic' : 10.0,
    'ode' : 500.0,
    'ed_b' : 10.0,
    'ed_p' : 50.0,
}

epochs = int(500e3)
for i in tqdm(range(epochs)):

    # def closure():
    #     optimizer.zero_grad()
    #     loss, losses = osa_model.loss_func(lambds)
    #     loss_hist.append([loss_it.item() for loss_it in losses] + [loss.item()])
    #     loss.backward()
    #     return loss
    
    # optimizer.step(closure)

    optimizer.zero_grad()
    loss, losses = osa_model.loss_func(lambds)
    loss_hist.append([loss_it.item() for loss_it in losses] + [loss.item()])
    loss.backward()
    optimizer.step()

    # osa_model.apply(clipper)

    if (i+1) % print_step == 0:

        x_pred = osa_model.predict()

        # x_pred, xpred_ed, t_ed = osa_model.predict()
        # var_pred = {
        #     "t_hat" : t_ed.detach(),
        #     "x_hat" : xpred_ed.detach()
        # }

        prediction = {
            "t_hat" : t_pred,
            "x_hat" : x_pred.detach()
        }

        plot_result(axs[0], ground_truth, data, prediction, alphas)

        plot_joint_loss_hist(axs[1], np.array(loss_hist))

        display.clear_output(wait=True)
        display.display(plt.gcf())
        match osa_model.param_type:
            case "constant":
                tqdma.write("Epoch : %d ---- Loss: %.2e" % (i+1,loss_hist[i][-1]))
            case "variable":
                tqdma.write("Epoch : %d ---- Loss: %.2e \nc_tild: %.4f ---- k_tild: %.4f" % (i+1,loss_hist[i][-1],osa_model.phys_params[0]*alphas['c'],osa_model.phys_params[1]*alphas['k']))

display.clear_output()
match osa_model.param_type:
    case "constant":
        tqdma.write("Epoch : %d ---- Loss: %.2e" % (i+1,loss_hist[i][-1]))
    case "variable":
        tqdma.write("Epoch : %d ---- Loss: %.2e \nc_tild: %.4f ---- k_tild: %.4f" % (i+1,loss_hist[i][-1],osa_model.phys_params[0]*alphas['c'],osa_model.phys_params[1]*alphas['k']))
# Out:
#  62%|██████▏   | 307599/500000 [30:12<18:53, 169.74it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 107
#     104 plot_joint_loss_hist(axs[1], np.array(loss_hist))
#     106 display.clear_output(wait=True)
# --> 107 display.display(plt.gcf())
#     108 match osa_model.param_type:
#     109     case "constant":
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/IPython/core/formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/IPython/core/formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/backend_bases.py:2346, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
# -> 2346         bbox_inches = self.figure.get_tightbbox(
#    2347             renderer, bbox_extra_artists=bbox_extra_artists)
#    2348         if pad_inches is None:
#    2349             pad_inches = rcParams['savefig.pad_inches']
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/figure.py:1744, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1741     artists = bbox_extra_artists
#    1743 for a in artists:
# -> 1744     bbox = a.get_tightbbox(renderer)
#    1745     if bbox is not None:
#    1746         bb.append(bbox)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/legend.py:1026, in Legend.get_tightbbox(self, renderer)
#    1024 def get_tightbbox(self, renderer=None):
#    1025     # docstring inherited
# -> 1026     return self._legend_box.get_window_extent(renderer)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/offsetbox.py:402, in OffsetBox.get_window_extent(self, renderer)
#     400 bbox = self.get_bbox(renderer)
#     401 try:  # Some subclasses redefine get_offset to take no args.
# --> 402     px, py = self.get_offset(bbox, renderer)
#     403 except TypeError:
#     404     px, py = self.get_offset()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/offsetbox.py:60, in _compat_get_offset.<locals>.get_offset(self, *args, **kwargs)
#      56 params = _api.select_matching_signature(sigs, self, *args, **kwargs)
#      57 bbox = (params["bbox"] if "bbox" in params else
#      58         Bbox.from_bounds(-params["xdescent"], -params["ydescent"],
#      59                          params["width"], params["height"]))
# ---> 60 return meth(params["self"], bbox, params["renderer"])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/offsetbox.py:313, in OffsetBox.get_offset(self, bbox, renderer)
#     298 @_compat_get_offset
#     299 def get_offset(self, bbox, renderer):
#     300     """
#     301     Return the offset as a tuple (x, y).
#     302
#    (...)
#     310     renderer : `.RendererBase` subclass
#     311     """
#     312     return (
# --> 313         self._offset(bbox.width, bbox.height, -bbox.x0, -bbox.y0, renderer)
#     314         if callable(self._offset)
#     315         else self._offset)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/legend.py:695, in Legend._findoffset(self, width, height, xdescent, ydescent, renderer)
#     692 """Helper function to locate the legend."""
#     694 if self._loc == 0:  # "best".
# --> 695     x, y = self._find_best_position(width, height, renderer)
#     696 elif self._loc in Legend.codes.values():  # Fixed location.
#     697     bbox = Bbox.from_bounds(0, 0, width, height)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/legend.py:1125, in Legend._find_best_position(self, width, height, renderer, consider)
#    1121 assert self.isaxes  # always holds, as this is only called internally
#    1123 start_time = time.perf_counter()
# -> 1125 bboxes, lines, offsets = self._auto_legend_data()
#    1127 bbox = Bbox.from_bounds(0, 0, width, height)
#    1128 if consider is None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/legend.py:928, in Legend._auto_legend_data(self)
#     925 for artist in self.parent._children:
#     926     if isinstance(artist, Line2D):
#     927         lines.append(
# --> 928             artist.get_transform().transform_path(artist.get_path()))
#     929     elif isinstance(artist, Rectangle):
#     930         bboxes.append(
#     931             artist.get_bbox().transformed(artist.get_data_transform()))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/transforms.py:1595, in Transform.transform_path(self, path)
#    1588 def transform_path(self, path):
#    1589     """
#    1590     Apply the transform to `.Path` *path*, returning a new `.Path`.
#    1591
#    1592     In some cases, this transform may insert curves into the path
#    1593     that began as line segments.
#    1594     """
# -> 1595     return self.transform_path_affine(self.transform_path_non_affine(path))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/transforms.py:2431, in CompositeGenericTransform.transform_path_non_affine(self, path)
#    2429     return path
#    2430 elif not self._a.is_affine and self._b.is_affine:
# -> 2431     return self._a.transform_path_non_affine(path)
#    2432 else:
#    2433     return self._b.transform_path_non_affine(
#    2434                             self._a.transform_path(path))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/transforms.py:1615, in Transform.transform_path_non_affine(self, path)
#    1607 def transform_path_non_affine(self, path):
#    1608     """
#    1609     Apply the non-affine part of this transform to `.Path` *path*,
#    1610     returning a new `.Path`.
#    (...)
#    1613     ``transform_path_affine(transform_path_non_affine(values))``.
#    1614     """
# -> 1615     x = self.transform_non_affine(path.vertices)
#    1616     return Path._fast_from_codes_and_verts(x, path.codes, path)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/transforms.py:2241, in BlendedGenericTransform.transform_non_affine(self, points)
#    2239     y_points = y.transform_non_affine(points)[:, 1:]
#    2240 else:
# -> 2241     y_points = y.transform_non_affine(points[:, 1])
#    2242     y_points = y_points.reshape((len(y_points), 1))
#    2244 if (isinstance(x_points, np.ma.MaskedArray) or
#    2245         isinstance(y_points, np.ma.MaskedArray)):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/matplotlib/scale.py:221, in LogTransform.transform_non_affine(self, a)
#     219 log = {np.e: np.log, 2: np.log2, 10: np.log10}.get(self.base)
#     220 if log:  # If possible, do everything in a single call to NumPy.
# --> 221     out = log(a)
#     222 else:
#     223     out = np.log(a)
#
# KeyboardInterrupt:

# %%
result_data = {
    'epoch' : i,
    'gt_config' : config,
    'osa_config' : osa_config,
    'model' : osa_model.state_dict(),
    'loss' : loss_hist,
    'ground_truth' : ground_truth,
    'data' : data,
    'prediction' : prediction,
    'alphas' : alphas
}

torch.save(result_data, 'results/osa_free_linear.pth')

# %%
# checkpoint = {
#     'epoch' : i,
#     'model' : osa_model.state_dict(),
#     'optimizer' : optimizer.state_dict(),
#     'loss' : loss_hist,
#     "sdof_config" : config,
#     "pinn_config" : osa_config
# }

# torch.save(checkpoint,'checkpoints/sdof_free_osa.pth')
