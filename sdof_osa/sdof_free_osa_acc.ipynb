# %% [markdown]
# # Linear SDOF PINN - n-step ahead prediction
#
# ## Problem overview
#
# The example problem we solve here is the SDOF cubic oscillator:
# $$
# m \ddot{x} + c\dot{x} + kx = 0~, \qquad \ddot{x} + \tilde{c}\dot{x} + \tilde{k}x = 0~, \qquad \tilde{\bullet}=\frac{\bullet}{m}
# $$
# with the initial conditions
# $$
# x(0) = x_0~~,~~\dot{x}(0) = \dot{x}_0
# $$
#
# The aim is to predict the output at one-step ahead, using the previous displacement and velocity;
# $$
# x_{n+1} = f(x_{n},\dot{x}_{n})
# $$
#
# For notation with the neural networks, we will denote,
# $$
# y = x_{n+1}, \qquad \mathbf{x} = \{ x_{n},\dot{x}_{n} \}
# $$

# %%
from osa_pinn import bbnn, osa_pinn_sdof_acc, normalise, ParamClipper
from sdof_oscillators import sdof_solution, add_noise, generate_excitation

import numpy as np
import torch
import torch.nn as nn
import mygrad as mg

from tqdm import tqdm
from tqdm.auto import tqdm as tqdma

import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nt = 256
time = np.linspace(0,40,nt)

F0 = 1.0  # N

excitation = {
    "type" : "sinusoid",
    "F0" : F0,
    "w" : 1.6  # rad/s
}

F = generate_excitation(time, **excitation)
excitation["F"] = F.reshape(-1)

# %% [markdown]
# ### Generate training/ground truth data

# %%
m = 10.0
c = 1.0
k = 15.0
excitation["F_tild"] = excitation["F"]/m

wn = np.sqrt(k/m)
zeta = c/(2*m*wn)
wd = wn*np.sqrt(1-zeta**2)

k_tild = k/m
c_tild = c/m

config = {
    "time_" : time,
    "nonlinearity" : "linear",
    "m_norm" : True,
    "params" : {
        "m" : m,
        "k" : k,
        "c" : c,
        "k_tild" : k_tild,
        "c_tild" : c_tild
    },
    "init_conds" : {
        "x0" : 0.01,
        "v0" : 0.05
    },
    "forcing" : None
}

xx, vv = sdof_solution(time, **config)
aa = -k_tild*xx - c_tild*vv
time = torch.tensor(time).view(-1,1).to(torch.float32)

# slice out a number of points
sub_ind = np.arange(0, int(nt/1), 8)

t_data = time[sub_ind]
x_data = xx[sub_ind]
v_data = vv[sub_ind]
a_data = aa[sub_ind]

T = t_data[1].item()-t_data[0].item()

fig, axs = plt.subplots(3,1,figsize=(12,8))

axs[0].plot(time, xx, color="tab:blue", label="Displacement")
axs[0].scatter(t_data, x_data, color="tab:orange", label="Training data")
axs[0].legend()

axs[1].plot(time, vv, color="tab:red", label="Velocity")
axs[1].scatter(t_data, v_data, color="tab:orange", label="Training data")
axs[1].legend()

axs[2].plot(time, aa, color="tab:olive", label="Acceleration")
axs[2].scatter(t_data, a_data, color="tab:orange", label="Training data")
axs[2].legend()

# %% [markdown]
# Normalise and create some plotting functions

# %%
t_hat, alpha_t = normalise(time, "range")
x_hat_gt, alpha_x = normalise(xx, "range")
v_hat_gt, alpha_v = normalise(vv, "range")
a_hat_gt, alpha_a = normalise(aa, "range")

t_data = t_hat[sub_ind]
x_data = x_hat_gt[sub_ind]
v_data = v_hat_gt[sub_ind]
a_data = a_hat_gt[sub_ind]

T_hat = t_data[1].item()-t_data[0].item()

fig, axs = plt.subplots(3,1,figsize=(12,8))

axs[0].plot(t_hat, x_hat_gt, color="tab:blue", label="Displacement")
axs[0].scatter(t_data, x_data, color="tab:orange", label="Training data")
axs[0].legend()

axs[1].plot(t_hat, v_hat_gt, color="tab:red", label="Velocity")
axs[1].scatter(t_data, v_data, color="tab:orange", label="Training data")
axs[1].legend()

axs[2].plot(t_hat, a_hat_gt, color="tab:olive", label="Velocity")
axs[2].scatter(t_data, a_data, color="tab:orange", label="Training data")
axs[2].legend()

# %%
def plot_joint_loss_hist(ax,loss_hist):
    n_epoch = len(loss_hist)
    labels = ["L_obs", "L_ic", "L_ode", "L"]
    colors = ["tab:blue", "tab:red", "tab:green", "black"]
    # labels = ["L_obs", "L_ic", "L_ode", "L_ed_b", "L_ed_p", "L"]
    # colors = ["tab:blue", "tab:red", "tab:green", "tab:orange", "tab:purple", "black"]
    ax.cla()
    for i in range(len(labels)):
        ax.plot(np.arange(1,n_epoch+1),loss_hist[:,i],color=colors[i],label=labels[i])
    ax.set_yscale('log')
    ax.legend()

def plot_result(ax, ground_truth, data, prediction, alphas, var_pred=None):
    ax.cla()
    ax.plot(ground_truth["t_hat"]*alphas["t"], ground_truth["x_hat"]*alphas["x"], color="grey", linewidth=2, alpha=0.8, label="Exact solution")
    ax.plot(prediction["t_hat"]*alphas["t"], prediction["x_hat"]*alphas["x"], color="tab:blue", linewidth=4, alpha=0.8, label="Neural network prediction")
    ax.scatter(data["t_hat"]*alphas["t"], data["x_hat"]*alphas["x"], s=60, color="tab:orange", alpha=0.4, label='Training data')
    if var_pred is not None:
        ax.plot(var_pred["t_hat"]*alphas["t"], var_pred["x_hat"]*alphas["x"], color="tab:cyan", alpha=0.4, label='Variable coll prediction')
    l = ax.legend(frameon=False, fontsize="large")
    xL = torch.amax(ground_truth["t_hat"])*alphas["t"]
    yL = torch.amax(torch.abs(ground_truth["x_hat"]))*alphas["x"]
    ax.set_xlim(-0.05*xL, 1.05*xL)
    ax.set_ylim(-1.1*yL, 1.1*yL)

ground_truth = {
    "t_hat" : t_hat,
    "x_hat" : x_hat_gt,
}

data = {
    "t_hat" : t_data,
    "x_hat" : x_data
}

# %% [markdown]
# ## PINN
#
# $$
# \mathcal{L}(x_0,v_0,t;\mathbf{\theta}) := \mathcal{L}_{obs} + \mathcal{L}_{ic} + \Lambda\mathcal{L}_{ode}
# $$
#
# $$
# \mathcal{L}_{obs} = \langle \hat{x}^* - \mathcal{N}_{\hat{x}} \rangle _{\Omega\in\{t=T\}}, \qquad
# \mathcal{L}_{ic} = \langle \alpha_{v}\hat{v}_0 - \frac{\alpha_x}{\alpha_t}\partial_{\hat{t}}\mathcal{N}_{\hat{x}} \rangle _{\Omega\in\{t=0\}}
# $$
# $$
# \mathcal{L}_{ode} = \langle \hat{m} \partial^2_{\hat{t}}\mathcal{N}_{\hat{x}} + \hat{c} \partial_{\hat{t}}\mathcal{N}_{\hat{x}} + \hat{k}\mathcal{N}_{\hat{x}} - \eta \hat{F}\rangle _{\Omega_d}
# $$
# where,
# $$ \mathcal{N}_{\bullet} = \mathcal{N}_{\bullet}(\mathbf{x};\mathbf{\theta}), \qquad
# \partial_{*}\bullet = \frac{\partial\bullet}{\partial *}, \qquad
# \partial^2_{*}\bullet = \frac{\partial^2\bullet}{\partial *^2}, \qquad
# \langle\bullet\rangle _{\Omega_{\kappa}} = \frac{1}{N_{\kappa}}\sum_{x\in\Omega_{\kappa}}\left|\left|\bullet\right|\right|^2 $$
#
# ODE loss function comes from including the normalisation of the parameters, then choosing the suitable range to aid optimisation.
#
# $$
# \frac{1}{\alpha_t^2} \partial^2_{\hat{t}}\hat{x} +
# \tilde{c}\frac{1}{\alpha_t}\partial_{\hat{t}}\hat{x} +
# \tilde{k} \hat{x} -
# \frac{\alpha_F}{\alpha_x} \hat{F} = 0
# \quad \rightarrow \quad
# \hat{m} \partial^2_{\hat{t}}\hat{x} +
# \hat{c} \partial_{\hat{t}}\hat{x} +
# \hat{k}\hat{x} - \eta\hat{F} = 0
# $$
# To scale loss function in a physically meaningful way, multiply the loss function by any of the following:
# $$
# \Lambda = 1, \alpha_t, \alpha_t^2, \alpha_x^, \alpha_F^{-1}
# $$

# %%
alpha_c = c_tild*10
alpha_k = k_tild*10
alphas = {
    "c" : alpha_c,
    "k" : alpha_k,
    "t" : alpha_t,
    "x" : alpha_x,
    "v" : alpha_v,
    "a" : alpha_a,
    "F" : 1.0
}

nct = 8  # number of collocation points in time window

torch.manual_seed(123)

osa_config = {
    "n_input" : 3,
    "n_output" : 1,
    "n_hidden" : 16,
    "n_layers" : 2,
    "T" : T,
    "T_hat" : T_hat,
    "nct" : nct,
    "nonlinearity" : "linear",
    # "phys_params" : {
    #     "par_type" : "variable",
    #     "k": 1.0,
    #     "c" : 1.0,
    #     "ed_nct" : 1024
    # },
    "phys_params" : {
        "par_type" : "constant",
        "k": k_tild,
        "c" : c_tild
    },
    "alphas" : alphas,
    "ode_norm_Lambda" : alpha_x.item(),
    "forcing" : config["forcing"]
}

# configure PINN
osa_model = osa_pinn_sdof_acc(osa_config)
t_pred = osa_model.set_colls_and_obs(t_data, x_data, a_data)

# configure optimiser
learning_rate = 1e-4
betas = (0.95,0.999)
optimizer = torch.optim.Adam(osa_model.parameters(), lr=learning_rate, betas=betas)

clipper = ParamClipper()

# learning_rate = 5e-3
# max_iter = 50
# optimizer = torch.optim.LBFGS(osa_model.parameters(), lr=learning_rate, max_iter=max_iter)

fig, axs = plt.subplots(1,2,figsize=(18,6),facecolor='w')
print_step = 200
loss_hist=[]
lambds = {
    'obs' : 1000.0,
    'ic' : 10.0,
    'ode' : 100.0,
    'ed_b' : 10.0,
    'ed_p' : 50.0,
}

epochs = int(500e3)
for i in tqdm(range(epochs)):

    # def closure():
    #     optimizer.zero_grad()
    #     loss, losses = osa_model.loss_func(lambds)
    #     loss_hist.append([loss_it.item() for loss_it in losses] + [loss.item()])
    #     loss.backward()
    #     return loss
    
    # optimizer.step(closure)

    optimizer.zero_grad()
    loss, losses = osa_model.loss_func(lambds)
    loss_hist.append([loss_it.item() for loss_it in losses] + [loss.item()])
    loss.backward()
    optimizer.step()

    osa_model.apply(clipper)

    if (i+1) % print_step == 0:

        x_pred = osa_model.predict()

        # x_pred, xpred_ed, t_ed = osa_model.predict()
        # var_pred = {
        #     "t_hat" : t_ed.detach(),
        #     "x_hat" : xpred_ed.detach()
        # }

        prediction = {
            "t_hat" : t_pred,
            "x_hat" : x_pred.detach()
        }

        plot_result(axs[0], ground_truth, data, prediction, alphas)

        plot_joint_loss_hist(axs[1], np.array(loss_hist))

        display.clear_output(wait=True)
        display.display(plt.gcf())
        match osa_model.param_type:
            case "constant":
                tqdma.write("Epoch : %d ---- Loss: %.2e" % (i+1,loss_hist[i][-1]))
            case "variable":
                tqdma.write("Epoch : %d ---- Loss: %.2e \nc_tild: %.4f ---- k_tild: %.4f" % (i+1,loss_hist[i][-1],osa_model.phys_params[0]*alphas['c'],osa_model.phys_params[1]*alphas['k']))

display.clear_output()
match osa_model.param_type:
    case "constant":
        tqdma.write("Epoch : %d ---- Loss: %.2e" % (i+1,loss_hist[i][-1]))
    case "variable":
        tqdma.write("Epoch : %d ---- Loss: %.2e \nc_tild: %.4f ---- k_tild: %.4f" % (i+1,loss_hist[i][-1],osa_model.phys_params[0]*alphas['c'],osa_model.phys_params[1]*alphas['k']))
# Out:
#  16%|█▌        | 80827/500000 [08:41<1:26:12, 81.04it/s]
# Epoch : 80800 ---- Loss: 3.96e-02
#  16%|█▌        | 80974/500000 [08:42<45:02, 155.05it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 81
#      69 for i in tqdm(range(epochs)):
#      70
#      71     # def closure():
#    (...)
#      77
#      78     # optimizer.step(closure)
#      80     optimizer.zero_grad()
# ---> 81     loss, losses = osa_model.loss_func(lambds)
#      82     loss_hist.append([loss_it.item() for loss_it in losses] + [loss.item()])
#      83     loss.backward()
#
# File ~/My Drive/Work/eth/experiments/dynamic_pinns_branching/sdof_osa/osa_pinn.py:648, in osa_pinn_sdof_acc.loss_func(self, lambdas)
#     647 def loss_func(self, lambdas):
# --> 648     residuals = self.calc_residuals()
#     649     R_obs = residuals["R_obs"]
#     650     R_ic = residuals["R_ic"]
#
# File ~/My Drive/Work/eth/experiments/dynamic_pinns_branching/sdof_osa/osa_pinn.py:571, in osa_pinn_sdof_acc.calc_residuals(self)
#     569 # retrieve derivatives
#     570 dx = torch.autograd.grad(xh_coll_hat, self.t_col, torch.ones_like(xh_coll_hat), create_graph=True)[0]  # ∂_t-hat N_y-hat
# --> 571 dx2 = torch.autograd.grad(dx, self.t_col, torch.ones_like(dx), create_graph=True)[0]  # ∂^2_t-hat N_y-hat
#     573 # generate predictions for equation discovery domain
#     574 match self.param_type:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch2-py310/lib/python3.10/site-packages/torch/autograd/__init__.py:303, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     301     return _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(grad_outputs_)
#     302 else:
# --> 303     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     304         t_outputs, grad_outputs_, retain_graph, create_graph, t_inputs,
#     305         allow_unused, accumulate_grad=False)
#
# KeyboardInterrupt:

# %%
checkpoint = {
    'epoch' : i,
    'model' : osa_model.state_dict(),
    'optimizer' : optimizer.state_dict(),
    'loss' : loss_hist,
    "sdof_config" : config,
    "pinn_config" : osa_config
}

torch.save(checkpoint,'checkpoints/sdof_free_osa.pth')
